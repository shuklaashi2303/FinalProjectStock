# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load
main_df = "Resources/constituents.csv"
stock_data = "Resources/constituents.csv"

# %%
# Read the School Data and Student Data and store into a Pandas DataFrame
main_df = pd.read_csv(main_df)
stock_data = pd.read_csv(stock_data)

# %%
main_df
# Out:
#     Symbol                 Name                  Sector
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4     ABMD              Abiomed             Health Care
# ..     ...                  ...                     ...
# 500    YUM          Yum! Brands  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
main_df.head()
# Out:
#   Symbol                 Name       Sector
# 0    MMM                   3M  Industrials
# 1    AOS          A. O. Smith  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV               AbbVie  Health Care
# 4   ABMD              Abiomed  Health Care

# %%
main_df.dtypes
# Out:
# Symbol    object
# Name      object
# Sector    object
# dtype: object

# %%
main_df.count()
# Out:
# Symbol    505
# Name      505
# Sector    505
# dtype: int64

# %%
main_df.sum()
# Out:
# Symbol    MMMAOSABTABBVABMDACNATVIADMADBEAAPAMDAESAFLAAP...
# Name      3MA. O. SmithAbbott LaboratoriesAbbVieAbiomedA...
# Sector    IndustrialsIndustrialsHealth CareHealth CareHe...
# dtype: object

# %%
main_df.mean()
# Out:
# Series([], dtype: float64)

# %%
main_df.isnull()
# Out:
#      Symbol   Name  Sector
# 0     False  False   False
# 1     False  False   False
# 2     False  False   False
# 3     False  False   False
# 4     False  False   False
# ..      ...    ...     ...
# 500   False  False   False
# 501   False  False   False
# 502   False  False   False
# 503   False  False   False
# 504   False  False   False
#
# [505 rows x 3 columns]

# %%
# Determine if there are any missing values in Main_df
main_df.isnull().sum()
# Out:
# Symbol    0
# Name      0
# Sector    0
# dtype: int64

# %%
# Determine if there are not any missing values in Main_df
main_df.notnull()
# Out:
#      Symbol  Name  Sector
# 0      True  True    True
# 1      True  True    True
# 2      True  True    True
# 3      True  True    True
# 4      True  True    True
# ..      ...   ...     ...
# 500    True  True    True
# 501    True  True    True
# 502    True  True    True
# 503    True  True    True
# 504    True  True    True
#
# [505 rows x 3 columns]

# %%
# Determine if there are not any missing values in Main_df
main_df.notnull().sum()
# Out:
# Symbol    505
# Name      505
# Sector    505
# dtype: int64

# %%
# Drop the NaNs for Main_df
main_df.dropna()
# Out:
#     Symbol                 Name                  Sector
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4     ABMD              Abiomed             Health Care
# ..     ...                  ...                     ...
# 500    YUM          Yum! Brands  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
stock_data
# Out:
#     Symbol                 Name                  Sector
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4     ABMD              Abiomed             Health Care
# ..     ...                  ...                     ...
# 500    YUM          Yum! Brands  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
stock_data.mean()
# Out:
# Series([], dtype: float64)

# %%
stock_data.dtypes
# Out:
# Symbol    object
# Name      object
# Sector    object
# dtype: object

# %%
stock_data.sum()
# Out:
# Symbol    MMMAOSABTABBVABMDACNATVIADMADBEAAPAMDAESAFLAAP...
# Name      3MA. O. SmithAbbott LaboratoriesAbbVieAbiomedA...
# Sector    IndustrialsIndustrialsHealth CareHealth CareHe...
# dtype: object

# %%
stock_data.isnull()
# Out:
#      Symbol   Name  Sector
# 0     False  False   False
# 1     False  False   False
# 2     False  False   False
# 3     False  False   False
# 4     False  False   False
# ..      ...    ...     ...
# 500   False  False   False
# 501   False  False   False
# 502   False  False   False
# 503   False  False   False
# 504   False  False   False
#
# [505 rows x 3 columns]

# %%
stock_data.isnull().sum()
# Out:
# Symbol    0
# Name      0
# Sector    0
# dtype: int64

# %%
stock_data.notnull()
# Out:
#      Symbol  Name  Sector
# 0      True  True    True
# 1      True  True    True
# 2      True  True    True
# 3      True  True    True
# 4      True  True    True
# ..      ...   ...     ...
# 500    True  True    True
# 501    True  True    True
# 502    True  True    True
# 503    True  True    True
# 504    True  True    True
#
# [505 rows x 3 columns]

# %%
stock_data.notnull().sum()
# Out:
# Symbol    505
# Name      505
# Sector    505
# dtype: int64

# %%
stock_data.dropna()
# Out:
#     Symbol                 Name                  Sector
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4     ABMD              Abiomed             Health Care
# ..     ...                  ...                     ...
# 500    YUM          Yum! Brands  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
# Combine the data into a single dataset
# total_data = pd.merge(main_df, stock_data, how="left", on=["main_df", "stock_data"])
# total_data.head()

# %%
#Create separate column with date column join with main_df & stock_data
new_data= stock_data.join(main_df, how="outer", lsuffix="_left", rsuffix="_right")

# %%
new_data
# Out:
#     Symbol_left            Name_left             Sector_left Symbol_right  \
# 0           MMM                   3M             Industrials          MMM
# 1           AOS          A. O. Smith             Industrials          AOS
# 2           ABT  Abbott Laboratories             Health Care          ABT
# 3          ABBV               AbbVie             Health Care         ABBV
# 4          ABMD              Abiomed             Health Care         ABMD
# ..          ...                  ...                     ...          ...
# 500         YUM          Yum! Brands  Consumer Discretionary          YUM
# 501        ZBRA   Zebra Technologies  Information Technology         ZBRA
# 502         ZBH        Zimmer Biomet             Health Care          ZBH
# 503        ZION        Zions Bancorp              Financials         ZION
# 504         ZTS               Zoetis             Health Care          ZTS
#
#               Name_right            Sector_right
# ...
